# %%
import pandas as pd

# %% [markdown]
# The first difference we'll note with Python and Pandas is that instead of selecting from a database, we'll be reading in individual files to query with Pandas. This is primarily a byproduct of _when_ we use tools like Pandas. Frequently, this _will not_ be against a database, as with SQL, but against structured or semi-structured data stored in JSON, CSV, parquet, or other formats.
#
# Here we're using `read_parquet` to pull in the corresponding parquet file for the Parks dataset.

# %%
parks_df = pd.read_parquet("../../data/nps/nps_public_data_parks.parquet")
parks_df.head()
# Out:
#    relevanceScore               designation  \
# 0               1         National Memorial
# 1               1   National Historic Trail
# 2               1
# 3               1  National Historical Park
# 4               1          Memorial Parkway
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
# 3  Be prepared for hot, humid weather. The histor...
# 4  Summers on the parkway are generally hot and h...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 2  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 4  [{'type': 'Physical', 'line2': '700 George Was...
#
#                                       operatingHours  \
# 0  [{'name': 'Hours of Operation', 'standardHours...
# 1  [{'name': 'Visitor Center Hours', 'standardHou...
# 2  [{'name': 'National Capital Parks-East Headqua...
# 3  [{'name': 'Visitor Center', 'standardHours': {...
# 4  [{'name': 'George Washington Memorial Parkway ...
#
#                                       entrancePasses  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'description': 'Adams National Historical Pa...
# 4                                                 []
#
#                           name  \
# 0                 Federal Hall
# 1                Lewis & Clark
# 2  National Capital Parks-East
# 3                        Adams
# 4            George Washington
#
#                                          description  \
# 0  Here on Wall Street, George Washington took th...
# 1  The Lewis and Clark National Historic Trail wi...
# 2  Welcome to National Capital Parks-East. We inv...
# 3  From the sweet little farm at the foot of Penn...
# 4  The George Washington Memorial Parkway was des...
#
#                                        directionsUrl fees  ...  \
# 0  http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 2  http://www.nps.gov/nace/planyourvisit/directio...   []  ...
# 3  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
# 4  http://www.nps.gov/gwmp/planyourvisit/directio...   []  ...
#
#                                           activities  \
# 0  [{'name': 'Arts and Culture', 'id': '09DF0950-...
# 1  [{'name': 'Auto and ATV', 'id': '5F723BAD-7359...
# 2  [{'name': 'Biking', 'id': '7CE6E935-F839-4FEC-...
# 3  [{'name': 'Guided Tours', 'id': 'B33DC9B6-0B7D...
# 4  [{'name': 'Arts and Culture', 'id': '09DF0950-...
#
#                                   url  longitude  \
# 0  https://www.nps.gov/feha/index.htm -74.010256
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 2  https://www.nps.gov/nace/index.htm -76.994000
# 3  https://www.nps.gov/adam/index.htm -71.011604
# 4  https://www.nps.gov/gwmp/index.htm -77.149500
#
#                                      id  \
# 0  2337D255-2D32-4997-957A-D461EEA03AF8
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 2  BA3C1A1D-AA6A-49EB-9237-0222CEEE2670
# 3  E4C7784E-66A0-4D44-87D0-3E072F5FEF43
# 4  E6D5BB41-3251-469F-ABDA-7B43B966F0CF
#
#                                               images  \
# 0  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 2  [{'url': 'https://www.nps.gov/common/uploads/s...
# 3  [{'url': 'https://www.nps.gov/common/uploads/s...
# 4  [{'url': 'https://www.nps.gov/common/uploads/s...
#
#                                       directionsInfo  \
# 0  The main entrance of Federal Hall is located a...
# 1  Lewis & Clark National Historic Trail Headquar...
# 2  DC295 South to the Exit for I-694/I-395/Capito...
# 3  Traveling on U.S. Interstate 93, take exit 7 -...
# 4  Directions to Parkway Headquarters From the so...
#
#                                 fullName parkCode  \
# 0         Federal Hall National Memorial     feha
# 1  Lewis & Clark National Historic Trail     lecl
# 2            National Capital Parks-East     nace
# 3         Adams National Historical Park     adam
# 4     George Washington Memorial Parkway     gwmp
#
#                                   latLong   latitude
# 0      lat:40.70731192, long:-74.01025636  40.707312
# 1  lat:41.2646141052, long:-95.9245147705  41.264614
# 2               lat:38.8659, long:-76.994  38.865900
# 3       lat:42.2553961, long:-71.01160356  42.255396
# 4              lat:38.9628, long:-77.1495  38.962800
#
# [5 rows x 24 columns]

# %% [markdown]
# Let's perform some similar operations to our DuckDB example— renaming a column and expanding the `STRUCT` column, `operatingHours`

# %%
from pprint import pprint

rename_dict = {"operatingHours": "operating_hours"}

# Note that rename requires casing and names to be precisely correct..
# It often won't throw errors if they are not, but it also won't rename the columns, so be sure to check.

parks_df.rename(columns=rename_dict, inplace=True)

pprint(list(parks_df.columns))
# Out:
# ['relevanceScore',
#  'designation',
#  'weatherInfo',
#  'addresses',
#  'operating_hours',
#  'entrancePasses',
#  'name',
#  'description',
#  'directionsUrl',
#  'fees',
#  'topics',
#  'states',
#  'entranceFees',
#  'contacts',
#  'activities',
#  'url',
#  'longitude',
#  'id',
#  'images',
#  'directionsInfo',
#  'fullName',
#  'parkCode',
#  'latLong',
#  'latitude']

# %%
# We can inspect the operating_hours column to better understand the data structure
# Let's look at a sample record

parks_df["operating_hours"].iloc[0]

# Note how we're "selecting" a column and then using the iloc method to get the first record.
# Out:
# array([{'name': 'Hours of Operation', 'standardHours': {'friday': '10:00AM - 5:00PM', 'sunday': 'Closed', 'thursday': '10:00AM - 5:00PM', 'tuesday': '10:00AM - 5:00PM', 'saturday': 'Closed', 'monday': '10:00AM - 5:00PM', 'wednesday': '10:00AM - 5:00PM'}, 'description': 'Federal Hall is Open.', 'exceptions': array([{'endDate': datetime.date(2025, 1, 15), 'name': 'Martin Luther King Jr. Day', 'startDate': datetime.date(2025, 1, 15), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 2, 19), 'name': "Washington's Birthday", 'startDate': datetime.date(2024, 2, 19), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 5, 27), 'name': 'Memorial Day', 'startDate': datetime.date(2024, 5, 27), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 6, 19), 'name': 'Juneteenth', 'startDate': datetime.date(2024, 6, 19), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': None, 'wednesday': '10:00AM - 5:00PM'}},
#               {'endDate': datetime.date(2024, 7, 4), 'name': 'Independence Day', 'startDate': datetime.date(2024, 7, 4), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': '10:00AM - 5:00PM', 'tuesday': None, 'saturday': None, 'monday': None, 'wednesday': None}},
#               {'endDate': datetime.date(2024, 9, 2), 'name': 'Labor Day', 'startDate': datetime.date(2024, 9, 2), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 10, 7), 'name': 'Columbus Day', 'startDate': datetime.date(2024, 10, 7), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 11, 11), 'name': 'Veterans Day', 'startDate': datetime.date(2024, 11, 11), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': '10:00AM - 5:00PM', 'wednesday': None}},
#               {'endDate': datetime.date(2024, 11, 28), 'name': 'Thanksgiving', 'startDate': datetime.date(2024, 11, 28), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': 'Closed', 'tuesday': None, 'saturday': None, 'monday': None, 'wednesday': None}},
#               {'endDate': datetime.date(2024, 12, 25), 'name': 'Christmas Day', 'startDate': datetime.date(2024, 12, 25), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': None, 'wednesday': 'Closed'}},
#               {'endDate': datetime.date(2025, 1, 1), 'name': "New Year's Day", 'startDate': datetime.date(2025, 1, 1), 'exceptionHours': {'friday': None, 'sunday': None, 'thursday': None, 'tuesday': None, 'saturday': None, 'monday': None, 'wednesday': 'Closed'}}],
#              dtype=object)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ],
#       dtype=object)

# %% [markdown]
# This record is a _list_ of dictionaries... That means we can't just unpack the values since each row could have more than one value. DuckDB handled that for us, but Pandas won't!
#
# This will be a theme throughout the remainder of the course. Certain tools might be more effective than others. It's our job to figure out what makes sense.

# %%
# The explode() method will unpack our list into individual rows
parks_df_exploded = parks_df.explode("operating_hours")
parks_df_exploded.head()
# Out:
#    relevanceScore               designation  \
# 0               1         National Memorial
# 1               1   National Historic Trail
# 2               1
# 3               1  National Historical Park
# 3               1  National Historical Park
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
# 3  Be prepared for hot, humid weather. The histor...
# 3  Be prepared for hot, humid weather. The histor...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 2  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
#
#                                      operating_hours  \
# 0  {'name': 'Hours of Operation', 'standardHours'...
# 1  {'name': 'Visitor Center Hours', 'standardHour...
# 2  {'name': 'National Capital Parks-East Headquar...
# 3  {'name': 'Visitor Center', 'standardHours': {'...
# 3  {'name': 'Historic Homes', 'standardHours': {'...
#
#                                       entrancePasses  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'description': 'Adams National Historical Pa...
# 3  [{'description': 'Adams National Historical Pa...
#
#                           name  \
# 0                 Federal Hall
# 1                Lewis & Clark
# 2  National Capital Parks-East
# 3                        Adams
# 3                        Adams
#
#                                          description  \
# 0  Here on Wall Street, George Washington took th...
# 1  The Lewis and Clark National Historic Trail wi...
# 2  Welcome to National Capital Parks-East. We inv...
# 3  From the sweet little farm at the foot of Penn...
# 3  From the sweet little farm at the foot of Penn...
#
#                                        directionsUrl fees  ...  \
# 0  http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 2  http://www.nps.gov/nace/planyourvisit/directio...   []  ...
# 3  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
# 3  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
#
#                                           activities  \
# 0  [{'name': 'Arts and Culture', 'id': '09DF0950-...
# 1  [{'name': 'Auto and ATV', 'id': '5F723BAD-7359...
# 2  [{'name': 'Biking', 'id': '7CE6E935-F839-4FEC-...
# 3  [{'name': 'Guided Tours', 'id': 'B33DC9B6-0B7D...
# 3  [{'name': 'Guided Tours', 'id': 'B33DC9B6-0B7D...
#
#                                   url  longitude  \
# 0  https://www.nps.gov/feha/index.htm -74.010256
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 2  https://www.nps.gov/nace/index.htm -76.994000
# 3  https://www.nps.gov/adam/index.htm -71.011604
# 3  https://www.nps.gov/adam/index.htm -71.011604
#
#                                      id  \
# 0  2337D255-2D32-4997-957A-D461EEA03AF8
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 2  BA3C1A1D-AA6A-49EB-9237-0222CEEE2670
# 3  E4C7784E-66A0-4D44-87D0-3E072F5FEF43
# 3  E4C7784E-66A0-4D44-87D0-3E072F5FEF43
#
#                                               images  \
# 0  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 2  [{'url': 'https://www.nps.gov/common/uploads/s...
# 3  [{'url': 'https://www.nps.gov/common/uploads/s...
# 3  [{'url': 'https://www.nps.gov/common/uploads/s...
#
#                                       directionsInfo  \
# 0  The main entrance of Federal Hall is located a...
# 1  Lewis & Clark National Historic Trail Headquar...
# 2  DC295 South to the Exit for I-694/I-395/Capito...
# 3  Traveling on U.S. Interstate 93, take exit 7 -...
# 3  Traveling on U.S. Interstate 93, take exit 7 -...
#
#                                 fullName parkCode  \
# 0         Federal Hall National Memorial     feha
# 1  Lewis & Clark National Historic Trail     lecl
# 2            National Capital Parks-East     nace
# 3         Adams National Historical Park     adam
# 3         Adams National Historical Park     adam
#
#                                   latLong   latitude
# 0      lat:40.70731192, long:-74.01025636  40.707312
# 1  lat:41.2646141052, long:-95.9245147705  41.264614
# 2               lat:38.8659, long:-76.994  38.865900
# 3       lat:42.2553961, long:-71.01160356  42.255396
# 3       lat:42.2553961, long:-71.01160356  42.255396
#
# [5 rows x 24 columns]

# %% [markdown]
# From there, we can unnest the operating hours column with `pd.json_normalize`

# %%
park_operating_hours_df = pd.json_normalize(parks_df_exploded["operating_hours"])

park_operating_hours_df.rename(
    columns={"name": "category", "description": "operating_hours_description"},
    inplace=True,
)

park_operating_hours_df.head()
# Out:
#                                    category  \
# 0                        Hours of Operation
# 1                      Visitor Center Hours
# 2  National Capital Parks-East Headquarters
# 3                            Visitor Center
# 4                            Historic Homes
#
#                          operating_hours_description  \
# 0                              Federal Hall is Open.
# 1  Lewis and Clark National Historic Trail Visito...
# 2  National Capital Parks-East is an administrati...
# 3  The Visitor Center is open Monday through Frid...
# 4  The historic homes are closed for the season. ...
#
#                                           exceptions standardHours.friday  \
# 0  [{'endDate': 2025-01-15, 'name': 'Martin Luthe...     10:00AM - 5:00PM
# 1  [{'endDate': 2024-10-28, 'name': 'SUMMER HOURS...      8:30AM - 4:30PM
# 2  [{'endDate': 2024-02-19, 'name': 'President's ...      8:00AM - 4:00PM
# 3  [{'endDate': 2024-05-27, 'name': 'Memorial Day...     10:00AM - 4:00PM
# 4  [{'endDate': 2024-06-19, 'name': 'Juneteenth N...               Closed
#
#   standardHours.sunday standardHours.thursday standardHours.tuesday  \
# 0               Closed       10:00AM - 5:00PM      10:00AM - 5:00PM
# 1               Closed        8:30AM - 4:30PM       8:30AM - 4:30PM
# 2               Closed        8:00AM - 4:00PM       8:00AM - 4:00PM
# 3               Closed       10:00AM - 4:00PM      10:00AM - 4:00PM
# 4               Closed                 Closed                Closed
#
#   standardHours.saturday standardHours.monday standardHours.wednesday
# 0                 Closed     10:00AM - 5:00PM        10:00AM - 5:00PM
# 1                 Closed      8:30AM - 4:30PM         8:30AM - 4:30PM
# 2                 Closed      8:00AM - 4:00PM         8:00AM - 4:00PM
# 3                 Closed     10:00AM - 4:00PM        10:00AM - 4:00PM
# 4                 Closed               Closed                  Closed

# %% [markdown]
# But now we have a separate dataframe! To join it back to our original df, we can use `pd.concat` with `axis=1`— that tells us to concatenate our dataframes by column.
#
# We also have to `reset_index` for each of our dataframes to ensure a true join. Yes, this is confusing. Unfortunately, the only way to learn is through trial, error, [StackOverflow](https://stackoverflow.com/a/47657006), and the Pandas [documentation](https://pandas.pydata.org/docs/reference/api/pandas.concat.html).

# %%
# Because the dataframes' order are identical, we can simply join them
parks_with_hours_df = pd.concat(
    [
        parks_df_exploded.reset_index(drop=True),
        park_operating_hours_df.reset_index(drop=True),
    ],
    axis=1,
)

parks_with_hours_df.head()
# Out:
#    relevanceScore               designation  \
# 0               1         National Memorial
# 1               1   National Historic Trail
# 2               1
# 3               1  National Historical Park
# 4               1  National Historical Park
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
# 3  Be prepared for hot, humid weather. The histor...
# 4  Be prepared for hot, humid weather. The histor...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 2  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 4  [{'type': 'Physical', 'line2': '', 'line1': '1...
#
#                                      operating_hours  \
# 0  {'name': 'Hours of Operation', 'standardHours'...
# 1  {'name': 'Visitor Center Hours', 'standardHour...
# 2  {'name': 'National Capital Parks-East Headquar...
# 3  {'name': 'Visitor Center', 'standardHours': {'...
# 4  {'name': 'Historic Homes', 'standardHours': {'...
#
#                                       entrancePasses  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'description': 'Adams National Historical Pa...
# 4  [{'description': 'Adams National Historical Pa...
#
#                           name  \
# 0                 Federal Hall
# 1                Lewis & Clark
# 2  National Capital Parks-East
# 3                        Adams
# 4                        Adams
#
#                                          description  \
# 0  Here on Wall Street, George Washington took th...
# 1  The Lewis and Clark National Historic Trail wi...
# 2  Welcome to National Capital Parks-East. We inv...
# 3  From the sweet little farm at the foot of Penn...
# 4  From the sweet little farm at the foot of Penn...
#
#                                        directionsUrl fees  ...  \
# 0  http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 2  http://www.nps.gov/nace/planyourvisit/directio...   []  ...
# 3  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
# 4  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
#
#                                    category  \
# 0                        Hours of Operation
# 1                      Visitor Center Hours
# 2  National Capital Parks-East Headquarters
# 3                            Visitor Center
# 4                            Historic Homes
#
#                          operating_hours_description  \
# 0                              Federal Hall is Open.
# 1  Lewis and Clark National Historic Trail Visito...
# 2  National Capital Parks-East is an administrati...
# 3  The Visitor Center is open Monday through Frid...
# 4  The historic homes are closed for the season. ...
#
#                                           exceptions standardHours.friday  \
# 0  [{'endDate': 2025-01-15, 'name': 'Martin Luthe...     10:00AM - 5:00PM
# 1  [{'endDate': 2024-10-28, 'name': 'SUMMER HOURS...      8:30AM - 4:30PM
# 2  [{'endDate': 2024-02-19, 'name': 'President's ...      8:00AM - 4:00PM
# 3  [{'endDate': 2024-05-27, 'name': 'Memorial Day...     10:00AM - 4:00PM
# 4  [{'endDate': 2024-06-19, 'name': 'Juneteenth N...               Closed
#
#   standardHours.sunday standardHours.thursday  standardHours.tuesday  \
# 0               Closed       10:00AM - 5:00PM       10:00AM - 5:00PM
# 1               Closed        8:30AM - 4:30PM        8:30AM - 4:30PM
# 2               Closed        8:00AM - 4:00PM        8:00AM - 4:00PM
# 3               Closed       10:00AM - 4:00PM       10:00AM - 4:00PM
# 4               Closed                 Closed                 Closed
#
#   standardHours.saturday standardHours.monday standardHours.wednesday
# 0                 Closed     10:00AM - 5:00PM        10:00AM - 5:00PM
# 1                 Closed      8:30AM - 4:30PM         8:30AM - 4:30PM
# 2                 Closed      8:00AM - 4:00PM         8:00AM - 4:00PM
# 3                 Closed     10:00AM - 4:00PM        10:00AM - 4:00PM
# 4                 Closed               Closed                  Closed
#
# [5 rows x 34 columns]

# %% [markdown]
# We can then perform filters, as in SQL

# %%
parks_with_hours_df[parks_with_hours_df["category"] == "Hours of Operation"]
# Out:
#      relevanceScore               designation  \
# 0                 1         National Memorial
# 417               1    National Historic Site
# 562               1  National Historical Park
# 612               1         National Memorial
#
#                                            weatherInfo  \
# 0    http://forecast.weather.gov/MapClick.php?CityN...
# 417  Spring: Temperature range from 30F-70F. Mostly...
# 562  Located above the heat of the low desert, Tuma...
# 612  Weather on the Outer Banks varies seasonally a...
#
#                                              addresses  \
# 0    [{'type': 'Physical', 'line2': '', 'line1': '1...
# 417  [{'type': 'Physical', 'line2': '', 'line1': '2...
# 562  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 612  [{'type': 'Physical', 'line2': '', 'line1': '1...
#
#                                        operating_hours  \
# 0    {'name': 'Hours of Operation', 'standardHours'...
# 417  {'name': 'Hours of Operation', 'standardHours'...
# 562  {'name': 'Hours of Operation', 'standardHours'...
# 612  {'name': 'Hours of Operation', 'standardHours'...
#
#                                         entrancePasses  \
# 0                                                   []
# 417                                                 []
# 562  [{'description': 'The annual pass at Tumacácor...
# 612                                                 []
#
#                               name  \
# 0                     Federal Hall
# 417  Theodore Roosevelt Birthplace
# 562                     Tumacácori
# 612                Wright Brothers
#
#                                            description  \
# 0    Here on Wall Street, George Washington took th...
# 417  This is the boyhood home of the first U.S. pre...
# 562  Tumacácori sits at a cultural crossroads in th...
# 612  Wind, sand, and a dream of flight brought Wilb...
#
#                                          directionsUrl fees  ...  \
# 0    http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 417  http://www.nps.gov/thrb/planyourvisit/directio...   []  ...
# 562  http://www.nps.gov/tuma/planyourvisit/directio...   []  ...
# 612  http://www.nps.gov/wrbr/planyourvisit/directio...   []  ...
#
#                category                        operating_hours_description  \
# 0    Hours of Operation                              Federal Hall is Open.
# 417  Hours of Operation  Theodore Roosevelt Birthplace National Histori...
# 562  Hours of Operation  These hours apply to the visitor center and mi...
# 612  Hours of Operation  These are the times the park grounds and visit...
#
#                                             exceptions standardHours.friday  \
# 0    [{'endDate': 2025-01-15, 'name': 'Martin Luthe...     10:00AM - 5:00PM
# 417                                                 []     10:00AM - 4:00PM
# 562  [{'endDate': 2024-11-28, 'name': 'Closed Thank...      9:00AM - 5:00PM
# 612  [{'endDate': 2024-12-25, 'name': 'Christmas Da...      9:00AM - 5:00PM
#
#     standardHours.sunday standardHours.thursday  standardHours.tuesday  \
# 0                 Closed       10:00AM - 5:00PM       10:00AM - 5:00PM
# 417     10:00AM - 4:00PM       10:00AM - 4:00PM                 Closed
# 562      9:00AM - 5:00PM        9:00AM - 5:00PM        9:00AM - 5:00PM
# 612      9:00AM - 5:00PM        9:00AM - 5:00PM        9:00AM - 5:00PM
#
#     standardHours.saturday standardHours.monday standardHours.wednesday
# 0                   Closed     10:00AM - 5:00PM        10:00AM - 5:00PM
# 417       10:00AM - 4:00PM               Closed        10:00AM - 4:00PM
# 562        9:00AM - 5:00PM      9:00AM - 5:00PM         9:00AM - 5:00PM
# 612        9:00AM - 5:00PM      9:00AM - 5:00PM         9:00AM - 5:00PM
#
# [4 rows x 34 columns]

# %% [markdown]
# Note the filter syntax:
#
# ```
# df[
#     df[column] [LOGICAL MODIFIER] [VALUE]
# ]
# ```
#
# we're taking the dataframe and applying a _mask_ where the column satisfies a certain condition. This is fundamentally different from filtering in SQL and can take some getting used to.
#
# For multiple filters, we can use the logical operators `& |` and parentheses for grouping, for example:
#
# ```
# df[
#     (CONDITION 1 & CONDITION 2) | CONDITION 3
# ]
# ```

# %%
# Let's get the hours of operation for Theodore Roosevelt National Park based on the description

parks_with_hours_df[
    (parks_with_hours_df["category"] == "Hours of Operation")
    & (
        parks_with_hours_df["operating_hours_description"].str.contains(
            "Theodore Roosevelt"
        )
    )
]

# Note the multiline formatting— this can directly improve readability
# Out:
#      relevanceScore             designation  \
# 417               1  National Historic Site
#
#                                            weatherInfo  \
# 417  Spring: Temperature range from 30F-70F. Mostly...
#
#                                              addresses  \
# 417  [{'type': 'Physical', 'line2': '', 'line1': '2...
#
#                                        operating_hours entrancePasses  \
# 417  {'name': 'Hours of Operation', 'standardHours'...             []
#
#                               name  \
# 417  Theodore Roosevelt Birthplace
#
#                                            description  \
# 417  This is the boyhood home of the first U.S. pre...
#
#                                          directionsUrl fees  ...  \
# 417  http://www.nps.gov/thrb/planyourvisit/directio...   []  ...
#
#                category                        operating_hours_description  \
# 417  Hours of Operation  Theodore Roosevelt Birthplace National Histori...
#
#     exceptions standardHours.friday standardHours.sunday  \
# 417         []     10:00AM - 4:00PM     10:00AM - 4:00PM
#
#     standardHours.thursday  standardHours.tuesday standardHours.saturday  \
# 417       10:00AM - 4:00PM                 Closed       10:00AM - 4:00PM
#
#     standardHours.monday standardHours.wednesday
# 417               Closed        10:00AM - 4:00PM
#
# [1 rows x 34 columns]

# %% [markdown]
# Distinct values can be accessed with the `unique()` method

# %%
pprint(list(parks_with_hours_df["standardHours.thursday"].unique())[:5])
# Out:
# ['10:00AM - 5:00PM',
#  '8:30AM - 4:30PM',
#  '8:00AM - 4:00PM',
#  '10:00AM - 4:00PM',
#  'Closed']

# %% [markdown]
# The Pandas equivalent of `CASE WHEN` is accessed through the numpy library `.where` function. If follows a similar pattern.
#
# We'll set a condition to select for— `parks_with_hours_df['standardHours.monday'] == 'unknown'`, if true, we'll return `Closed`. If not, we'll return the existing value.

# %%
import numpy as np

# CASE monday WHEN 'unknown' THEN 'Closed' ELSE monday END as monday_hours,

parks_with_hours_df["monday_hours"] = np.where(
    parks_with_hours_df["standardHours.monday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.monday"],
)
parks_with_hours_df["tuesday_hours"] = np.where(
    parks_with_hours_df["standardHours.tuesday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.tuesday"],
)
parks_with_hours_df["wednesday_hours"] = np.where(
    parks_with_hours_df["standardHours.wednesday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.wednesday"],
)
parks_with_hours_df["thursday_hours"] = np.where(
    parks_with_hours_df["standardHours.thursday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.thursday"],
)
parks_with_hours_df["friday_hours"] = np.where(
    parks_with_hours_df["standardHours.friday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.friday"],
)
parks_with_hours_df["saturday_hours"] = np.where(
    parks_with_hours_df["standardHours.saturday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.saturday"],
)
parks_with_hours_df["sunday_hours"] = np.where(
    parks_with_hours_df["standardHours.sunday"] == "unknown",
    "Closed",
    parks_with_hours_df["standardHours.sunday"],
)


parks_with_hours_df["open_seven_days_a_week"] = np.where(
    (
        (parks_with_hours_df["monday_hours"] != "Closed")
        & (parks_with_hours_df["tuesday_hours"] != "Closed")
        & (parks_with_hours_df["wednesday_hours"] != "Closed")
        & (parks_with_hours_df["thursday_hours"] != "Closed")
        & (parks_with_hours_df["friday_hours"] != "Closed")
        & (parks_with_hours_df["saturday_hours"] != "Closed")
        & (parks_with_hours_df["sunday_hours"] != "Closed")
    ),
    True,
    False,
)

cols_to_select = [
    "fullName",
    "open_seven_days_a_week",
    "monday_hours",
    "tuesday_hours",
    "wednesday_hours",
    "thursday_hours",
    "friday_hours",
    "saturday_hours",
    "sunday_hours",
]

parks_with_hours_df[cols_to_select].head()
# Out:
#                                 fullName  open_seven_days_a_week  \
# 0         Federal Hall National Memorial                   False
# 1  Lewis & Clark National Historic Trail                   False
# 2            National Capital Parks-East                   False
# 3         Adams National Historical Park                   False
# 4         Adams National Historical Park                   False
#
#        monday_hours     tuesday_hours   wednesday_hours    thursday_hours  \
# 0  10:00AM - 5:00PM  10:00AM - 5:00PM  10:00AM - 5:00PM  10:00AM - 5:00PM
# 1   8:30AM - 4:30PM   8:30AM - 4:30PM   8:30AM - 4:30PM   8:30AM - 4:30PM
# 2   8:00AM - 4:00PM   8:00AM - 4:00PM   8:00AM - 4:00PM   8:00AM - 4:00PM
# 3  10:00AM - 4:00PM  10:00AM - 4:00PM  10:00AM - 4:00PM  10:00AM - 4:00PM
# 4            Closed            Closed            Closed            Closed
#
#        friday_hours saturday_hours sunday_hours
# 0  10:00AM - 5:00PM         Closed       Closed
# 1   8:30AM - 4:30PM         Closed       Closed
# 2   8:00AM - 4:00PM         Closed       Closed
# 3  10:00AM - 4:00PM         Closed       Closed
# 4            Closed         Closed       Closed

# %% [markdown]
# Now you might be saying "gee Matt, that's a lot of code," and you'd be right! But that's one of the core lessons of this course— some things take lots of work in Python that are easy in SQL... but the opposite is true, too!
#
# Now we can filter our dataframe to create a new one:

# %%
open_seven_days_df = parks_with_hours_df[parks_with_hours_df["open_seven_days_a_week"]]

open_seven_days_df[cols_to_select].head()
# Out:
#                                     fullName  open_seven_days_a_week  \
# 6         George Washington Memorial Parkway                    True
# 8   Eleanor Roosevelt National Historic Site                    True
# 10       Morristown National Historical Park                    True
# 14            Cedar Breaks National Monument                    True
# 15         Devils Postpile National Monument                    True
#
#        monday_hours    tuesday_hours  wednesday_hours   thursday_hours  \
# 6           All Day          All Day          All Day          All Day
# 8   7:00AM - 5:00PM  7:00AM - 5:00PM  7:00AM - 5:00PM  7:00AM - 5:00PM
# 10  8:00AM - 5:00PM  8:00AM - 5:00PM  8:00AM - 5:00PM  8:00AM - 5:00PM
# 14          All Day          All Day          All Day          All Day
# 15          All Day          All Day          All Day          All Day
#
#        friday_hours   saturday_hours     sunday_hours
# 6           All Day          All Day          All Day
# 8   7:00AM - 5:00PM  7:00AM - 5:00PM  7:00AM - 5:00PM
# 10  8:00AM - 5:00PM  8:00AM - 5:00PM  8:00AM - 5:00PM
# 14          All Day          All Day          All Day
# 15          All Day          All Day          All Day

# %% [markdown]
# & save it off to a new file

# %%
open_seven_days_df.to_parquet("../../data/pandas/open_seven_days_df.parquet")
