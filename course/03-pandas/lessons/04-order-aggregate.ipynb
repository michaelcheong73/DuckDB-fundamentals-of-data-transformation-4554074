# %%
import pandas as pd
import numpy as np

parks_df = pd.read_parquet("../../data/nps/nps_public_data_parks.parquet")
parks_df.head()
# Out:
#    relevanceScore               designation  \
# 0               1         National Memorial
# 1               1   National Historic Trail
# 2               1
# 3               1  National Historical Park
# 4               1          Memorial Parkway
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 2  Summers are generally hot and humid, with dayt...
# 3  Be prepared for hot, humid weather. The histor...
# 4  Summers on the parkway are generally hot and h...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 2  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 3  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 4  [{'type': 'Physical', 'line2': '700 George Was...
#
#                                       operatingHours  \
# 0  [{'name': 'Hours of Operation', 'standardHours...
# 1  [{'name': 'Visitor Center Hours', 'standardHou...
# 2  [{'name': 'National Capital Parks-East Headqua...
# 3  [{'name': 'Visitor Center', 'standardHours': {...
# 4  [{'name': 'George Washington Memorial Parkway ...
#
#                                       entrancePasses  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'description': 'Adams National Historical Pa...
# 4                                                 []
#
#                           name  \
# 0                 Federal Hall
# 1                Lewis & Clark
# 2  National Capital Parks-East
# 3                        Adams
# 4            George Washington
#
#                                          description  \
# 0  Here on Wall Street, George Washington took th...
# 1  The Lewis and Clark National Historic Trail wi...
# 2  Welcome to National Capital Parks-East. We inv...
# 3  From the sweet little farm at the foot of Penn...
# 4  The George Washington Memorial Parkway was des...
#
#                                        directionsUrl fees  ...  \
# 0  http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 2  http://www.nps.gov/nace/planyourvisit/directio...   []  ...
# 3  http://www.nps.gov/adam/planyourvisit/directio...   []  ...
# 4  http://www.nps.gov/gwmp/planyourvisit/directio...   []  ...
#
#                                           activities  \
# 0  [{'name': 'Arts and Culture', 'id': '09DF0950-...
# 1  [{'name': 'Auto and ATV', 'id': '5F723BAD-7359...
# 2  [{'name': 'Biking', 'id': '7CE6E935-F839-4FEC-...
# 3  [{'name': 'Guided Tours', 'id': 'B33DC9B6-0B7D...
# 4  [{'name': 'Arts and Culture', 'id': '09DF0950-...
#
#                                   url  longitude  \
# 0  https://www.nps.gov/feha/index.htm -74.010256
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 2  https://www.nps.gov/nace/index.htm -76.994000
# 3  https://www.nps.gov/adam/index.htm -71.011604
# 4  https://www.nps.gov/gwmp/index.htm -77.149500
#
#                                      id  \
# 0  2337D255-2D32-4997-957A-D461EEA03AF8
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 2  BA3C1A1D-AA6A-49EB-9237-0222CEEE2670
# 3  E4C7784E-66A0-4D44-87D0-3E072F5FEF43
# 4  E6D5BB41-3251-469F-ABDA-7B43B966F0CF
#
#                                               images  \
# 0  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 2  [{'url': 'https://www.nps.gov/common/uploads/s...
# 3  [{'url': 'https://www.nps.gov/common/uploads/s...
# 4  [{'url': 'https://www.nps.gov/common/uploads/s...
#
#                                       directionsInfo  \
# 0  The main entrance of Federal Hall is located a...
# 1  Lewis & Clark National Historic Trail Headquar...
# 2  DC295 South to the Exit for I-694/I-395/Capito...
# 3  Traveling on U.S. Interstate 93, take exit 7 -...
# 4  Directions to Parkway Headquarters From the so...
#
#                                 fullName parkCode  \
# 0         Federal Hall National Memorial     feha
# 1  Lewis & Clark National Historic Trail     lecl
# 2            National Capital Parks-East     nace
# 3         Adams National Historical Park     adam
# 4     George Washington Memorial Parkway     gwmp
#
#                                   latLong   latitude
# 0      lat:40.70731192, long:-74.01025636  40.707312
# 1  lat:41.2646141052, long:-95.9245147705  41.264614
# 2               lat:38.8659, long:-76.994  38.865900
# 3       lat:42.2553961, long:-71.01160356  42.255396
# 4              lat:38.9628, long:-77.1495  38.962800
#
# [5 rows x 24 columns]

# %% [markdown]
# Coming directly from a SQL module on transformation, we'll approach aggregations similarly via Pandas— that means we're assuming you've completed module 2 _or_ have a basic understanding of SQL `GROUP` functionality.
#
# Pandas `groupby` works quite similarly to SQL, with a Pythonic twist:

# %%
# In the groupby method, we specify the column we want to group by, and then the column we want to count in brackets.

parks_df.groupby("states")["states"].count()
# Out:
# states
# AK                            19
# AL                             8
# AL,AR,GA,IL,KY,MO,NC,OK,TN     1
# AL,MS,TN                       2
# AR                             6
#                               ..
# WI                             2
# WI,MN                          1
# WV                             3
# WV,VA,MD                       1
# WY                             4
# Name: states, Length: 112, dtype: int64

# %% [markdown]
# Of course, we'll need to do something similar with states here, but think in terms of Python— create a new column by _splitting_ `states` on the comma separator to convert it to a list.

# %%
parks_df["states_list"] = parks_df["states"].str.split(",")

# %%
parks_df["states_list"].head()
# Out:
# 0                                                 [NY]
# 1    [IA, ID, IL, IN, KS, KY, MO, MT, NE, ND, OH, O...
# 2                                                 [DC]
# 3                                                 [MA]
# 4                                         [DC, MD, VA]
# Name: states_list, dtype: object

# %% [markdown]
# Now we can perform an `explode` like we did in lesson 1

# %%
parks_exploded_df = parks_df.explode("states_list").rename(
    columns={"states_list": "state"}
)
parks_exploded_df.head(5)
# Out:
#    relevanceScore              designation  \
# 0               1        National Memorial
# 1               1  National Historic Trail
# 1               1  National Historic Trail
# 1               1  National Historic Trail
# 1               1  National Historic Trail
#
#                                          weatherInfo  \
# 0  http://forecast.weather.gov/MapClick.php?CityN...
# 1  In winter, watch for ice on trails and sidewal...
# 1  In winter, watch for ice on trails and sidewal...
# 1  In winter, watch for ice on trails and sidewal...
# 1  In winter, watch for ice on trails and sidewal...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': '', 'line1': '1...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
# 1  [{'type': 'Physical', 'line2': '', 'line1': '6...
#
#                                       operatingHours entrancePasses  \
# 0  [{'name': 'Hours of Operation', 'standardHours...             []
# 1  [{'name': 'Visitor Center Hours', 'standardHou...             []
# 1  [{'name': 'Visitor Center Hours', 'standardHou...             []
# 1  [{'name': 'Visitor Center Hours', 'standardHou...             []
# 1  [{'name': 'Visitor Center Hours', 'standardHou...             []
#
#             name                                        description  \
# 0   Federal Hall  Here on Wall Street, George Washington took th...
# 1  Lewis & Clark  The Lewis and Clark National Historic Trail wi...
# 1  Lewis & Clark  The Lewis and Clark National Historic Trail wi...
# 1  Lewis & Clark  The Lewis and Clark National Historic Trail wi...
# 1  Lewis & Clark  The Lewis and Clark National Historic Trail wi...
#
#                                        directionsUrl fees  ...  \
# 0  http://www.nps.gov/feha/planyourvisit/directio...   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
# 1                          https://www.nps.gov/lecl/   []  ...
#
#                                   url  longitude  \
# 0  https://www.nps.gov/feha/index.htm -74.010256
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 1  https://www.nps.gov/lecl/index.htm -95.924515
# 1  https://www.nps.gov/lecl/index.htm -95.924515
#
#                                      id  \
# 0  2337D255-2D32-4997-957A-D461EEA03AF8
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
# 1  5D443C5F-19A0-4A06-9CE4-30534A3DD81A
#
#                                               images  \
# 0  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
#
#                                       directionsInfo  \
# 0  The main entrance of Federal Hall is located a...
# 1  Lewis & Clark National Historic Trail Headquar...
# 1  Lewis & Clark National Historic Trail Headquar...
# 1  Lewis & Clark National Historic Trail Headquar...
# 1  Lewis & Clark National Historic Trail Headquar...
#
#                                 fullName  parkCode  \
# 0         Federal Hall National Memorial      feha
# 1  Lewis & Clark National Historic Trail      lecl
# 1  Lewis & Clark National Historic Trail      lecl
# 1  Lewis & Clark National Historic Trail      lecl
# 1  Lewis & Clark National Historic Trail      lecl
#
#                                   latLong   latitude state
# 0      lat:40.70731192, long:-74.01025636  40.707312    NY
# 1  lat:41.2646141052, long:-95.9245147705  41.264614    IA
# 1  lat:41.2646141052, long:-95.9245147705  41.264614    ID
# 1  lat:41.2646141052, long:-95.9245147705  41.264614    IL
# 1  lat:41.2646141052, long:-95.9245147705  41.264614    IN
#
# [5 rows x 25 columns]

# %% [markdown]
# Finally, we can perform a groupby in pandas:

# %%
parks_exploded_df.groupby("state")["state"].count()[:5]
# Out:
# state
# AK    19
# AL    11
# AR     9
# AS     1
# AZ    25
# Name: state, dtype: int64

# %% [markdown]
# Above, we used the slice to obtain the top 5 results. We can sort the results of _any_ dataframe using `sort_values`

# %%
parks_exploded_df.groupby("state")["state"].count().sort_values(ascending=False)[:5]
# Out:
# state
# DC    36
# CA    34
# VA    33
# NY    32
# MD    27
# Name: state, dtype: int64

# %% [markdown]
# But what if we only want those designated as National Parks?

# %%
national_park_count_df = (
    parks_exploded_df[parks_exploded_df["designation"] == "National Park"]
    .groupby("state")["state"]
    .count()
    .sort_values(ascending=False)[:5]
)

# %% [markdown]
# Note how we formatted our query— by using parenthesis `()`, we were able to split the query into multiple lines and organize the operations. That makes it much easier to read then the alternative. The same can be accomplished with backslashes.

# %%
national_park_count_df = (
    parks_exploded_df[parks_exploded_df["designation"] == "National Park"]
    .groupby("state")["state"]
    .count()
    .sort_values(ascending=False)[:5]
)

national_park_count_df
# Out:
# state
# CA    6
# UT    5
# AZ    3
# CO    3
# FL    3
# Name: state, dtype: int64

# %% [markdown]
# Like our earlier example, let's find campgrounds with the least & most sites

# %%
campgrounds_df = pd.read_parquet("../../data/nps/nps_public_data_campgrounds.parquet")
campgrounds_df.head()
# Out:
#   lastIndexedDate  relevanceScore  \
# 0                             1.0
# 1                             1.0
# 2                             1.0
# 3                             1.0
# 4                             1.0
#
#                                        accessibility  \
# 0  {'classifications': ['Designated Primitive Cam...
# 1  {'classifications': ['Developed Campground'], ...
# 2  {'classifications': ['Developed Campground'], ...
# 3  {'classifications': ['Developed Campground'], ...
# 4  {'classifications': ['Developed Campground'], ...
#
#    numberOfSitesFirstComeFirstServe  numberOfSitesReservable multimedia  \
# 0                                 8                        0         []
# 1                                54                       27         []
# 2                                77                       31         []
# 3                                98                       92         []
# 4                                25                       39         []
#
#                                      weatherOverview  \
# 0  See weather information for Lovell, WY or Brid...
# 1  The Parkway varies in elevation from under 650...
# 2  The Parkway varies in elevation from under 650...
# 3  The Parkway varies in elevation from under 650...
# 4  The Parkway varies in elevation from under 650...
#
#                                               images  \
# 0  [{'url': 'https://www.nps.gov/common/uploads/s...
# 1  [{'url': 'https://www.nps.gov/common/uploads/s...
# 2  [{'url': 'https://www.nps.gov/common/uploads/s...
# 3  [{'url': 'https://www.nps.gov/common/uploads/s...
# 4  [{'url': 'https://www.nps.gov/common/uploads/s...
#
#                                            addresses  \
# 0  [{'type': 'Physical', 'line2': 'Dayboard 32 - ...
# 1  [{'type': 'Physical', 'line2': 'Blue Ridge Par...
# 2  [{'type': 'Physical', 'line2': 'Blue Ridge Par...
# 3  [{'type': 'Physical', 'line2': 'Blue Ridge Par...
# 4  [{'type': 'Physical', 'line2': 'Blue Ridge Par...
#
#                                            campsites  ... audioDescription  \
# 0  {'walkBoatTo': 5, 'tentOnly': 5, 'horse': 0, '...  ...
# 1  {'walkBoatTo': 0, 'tentOnly': 0, 'horse': 0, '...  ...
# 2  {'walkBoatTo': 0, 'tentOnly': 75, 'horse': 0, ...  ...
# 3  {'walkBoatTo': 0, 'tentOnly': 90, 'horse': 0, ...  ...
# 4  {'walkBoatTo': 0, 'tentOnly': 14, 'horse': 0, ...  ...
#
#   parkCode                                  latLong  \
# 0     bica   {lat:45.110180659, lng:-108.204311581}
# 1     blri    {lat:35.815386046, lng:-82.145568973}
# 2     blri    {lat:36.429492646, lng:-81.155775872}
# 3     blri    {lat:36.120349346, lng:-81.765269873}
# 4     blri  {lat:35.9671524465, lng:-81.9326240728}
#
#                                  regulationsOverview passportStampImages  \
# 0  1. Overnight stays/camping in park is only all...                  []
# 1                                                                     []
# 2                                                                     []
# 3                                                                     []
# 4                                                                     []
#
#     latitude                                                url   longitude  \
# 0  45.110181  https://www.nps.gov/bica/planyourvisit/medicin... -108.204312
# 1  35.815386  https://www.nps.gov/blri/planyourvisit/crabtre...  -82.145569
# 2  36.429493  https://www.nps.gov/blri/planyourvisit/doughto...  -81.155776
# 3  36.120349  https://www.nps.gov/blri/planyourvisit/price-c...  -81.765270
# 4  35.967152  https://www.nps.gov/blri/planyourvisit/linvill...  -81.932624
#
#                                             contacts  \
# 0  {'emailAddresses': [{'emailAddress': 'BICA_med...
# 1  {'emailAddresses': [{'emailAddress': 'blri_inf...
# 2  {'emailAddresses': [{'emailAddress': 'blri_inf...
# 3  {'emailAddresses': [{'emailAddress': 'blri_inf...
# 4  {'emailAddresses': [{'emailAddress': 'blri_inf...
#
#                                      id
# 0  59D597C2-D37E-41A8-AEBA-FA0D219280D4
# 1  B7FFF416-1181-4457-931B-6F9920C0EFE7
# 2  298C9FE2-25B3-4A60-BE23-76E43A703FC5
# 3  04662D80-18F0-4E2C-8C6A-461E244DB0A7
# 4  C32CB41B-1C35-454B-B9FD-AE3F71EEBDC8
#
# [5 rows x 33 columns]

# %%
campgrounds_df["total_sites"] = (
    campgrounds_df["numberOfSitesFirstComeFirstServe"]
    + campgrounds_df["numberOfSitesReservable"]
)

national_park_campgrounds_df = campgrounds_df.merge(
    parks_df, on="parkCode", how="inner", suffixes=("_campground", "_park")
)

national_park_campgrounds_df = national_park_campgrounds_df[
    (national_park_campgrounds_df["designation"] == "National Park")
    & (national_park_campgrounds_df["total_sites"] > 0)
]

# %%
min_sites = national_park_campgrounds_df["total_sites"].min()

max_sites = national_park_campgrounds_df["total_sites"].max()

min_max_df = national_park_campgrounds_df[
    (national_park_campgrounds_df["total_sites"] == min_sites)
    | (national_park_campgrounds_df["total_sites"] == max_sites)
]

min_max_df["min_max"] = np.where(
    min_max_df["total_sites"] == min_sites,
    "min",
    np.where(min_max_df["total_sites"] == max_sites, "max", "other"),
)
# Out:
# /tmp/ipykernel_25486/3017863287.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_max_df["min_max"] = np.where(

# %%
min_max_df[["fullName", "name_campground", "total_sites", "min_max"]].sort_values(
    by="total_sites", ascending=False
)
# Out:
#                               fullName                     name_campground  \
# 544           Mesa Verde National Park                Morefield Campground
# 97   Guadalupe Mountains National Park     Frijole Horse Corral Campground
# 181   Theodore Roosevelt National Park            Roundup Group Horse Camp
# 206         Capitol Reef National Park                      Group Campsite
# 272       North Cascades National Park  Upper Goodell Creek Group Campsite
# 462        Indiana Dunes National Park                   Dunbar Group Site
# 474          Isle Royale National Park                  Hay Bay Campground
# 487          Isle Royale National Park            Pickerel Cove Campground
#
#      total_sites min_max
# 544          534     max
# 97             1     min
# 181            1     min
# 206            1     min
# 272            1     min
# 462            1     min
# 474            1     min
# 487            1     min

# %%
max_sites
# Out:
# 534

# %% [markdown]
# What about the parks? Now, we just need to group by park!

# %%
min_sites_park = national_park_campgrounds_df.groupby(["fullName"])["total_sites"].min()

max_sites_park = national_park_campgrounds_df.groupby(["fullName"])["total_sites"].max()

park_campgrounds_agg = (
    national_park_campgrounds_df.groupby("fullName")["total_sites"]
    .sum()
    .sort_values(ascending=False)
)

park_campgrounds_agg
# Out:
# fullName
# Yellowstone National Park                     2149
# Yosemite National Park                        1362
# Grand Teton National Park                     1220
# Glacier National Park                         1010
# Great Smoky Mountains National Park            943
# Olympic National Park                          782
# Death Valley National Park                     761
# Shenandoah National Park                       603
# Acadia National Park                           577
# Grand Canyon National Park                     565
# Rocky Mountain National Park                   543
# Mesa Verde National Park                       534
# Joshua Tree National Park                      500
# Lassen Volcanic National Park                  448
# Mount Rainier National Park                    446
# Everglades National Park                       403
# North Cascades National Park                   379
# Zion National Park                             299
# Bryce Canyon National Park                     294
# Isle Royale National Park                      244
# Crater Lake National Park                      230
# Big Bend National Park                         196
# Pinnacles National Park                        139
# Great Basin National Park                      136
# Mammoth Cave National Park                     131
# Theodore Roosevelt National Park               125
# Wind Cave National Park                        124
# Black Canyon Of The Gunnison National Park     116
# Guadalupe Mountains National Park              110
# Channel Islands National Park                  106
# Badlands National Park                          96
# Capitol Reef National Park                      77
# Indiana Dunes National Park                     77
# Biscayne National Park                          60
# Arches National Park                            51
# Virgin Islands National Park                    50
# Hawaiʻi Volcanoes National Park                 41
# Canyonlands National Park                       40
# Congaree National Park                          40
# Hot Springs National Park                       40
# Haleakalā National Park                         28
# Kenai Fjords National Park                      12
# Saguaro National Park                           12
# White Sands National Park                       10
# Dry Tortugas National Park                       8
# Name: total_sites, dtype: int64

# %% [markdown]
# Groupby is pretty similar to the SQL equivalent! You can perform all sorts of basic groups. If you'd like to play around with more Groupby examples, check out the Pandas [docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)!
